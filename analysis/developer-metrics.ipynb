# %%
import pandas as pd
pd.options.display.float_format = '{:,}'.format

# %%
filename = '../data/coin_metrics.csv'
df = pd.read_csv(filename)

# %%
developer_columns = ['coin_name', 'coin_id', 'volume_24h', 'forks', 'stars', 'subscribers', 
    'total_issues', 'closed_issues', 'pull_requests_merged', 'pull_request_contributors']

(
    df[developer_columns]
       .sort_values('stars', ascending=False)
       .head(20)
)
# Out:
#           coin_name           coin_id      volume_24h  forks  stars  \
# 25         Polkadot          polkadot 1,778,582,619.0   1059   5018
# 24        Avalanche       avalanche-2 1,300,748,454.0    269   1318
# 0            Cosmos            cosmos 2,483,887,593.0    244   1038
# 5     Akash Network     akash-network     3,607,650.0     99    542
# 1              Kava              kava    81,986,583.0    228    317
# 9   Crypto.com Coin  crypto-com-chain   351,203,372.0    216    306
# 12          Osmosis           osmosis    83,287,642.0     87    301
# 20         Wanchain          wanchain     4,355,807.0     85    277
# 4     Band Protocol     band-protocol   136,099,485.0     53    218
# 22             ICON              icon    61,118,427.0     32     74
# 10         Sifchain          sifchain     5,052,106.0     84     69
# 16       Verus Coin        verus-coin        21,920.0     42     57
# 8          Fetch.ai          fetch-ai   125,737,395.0     17     29
# ...
